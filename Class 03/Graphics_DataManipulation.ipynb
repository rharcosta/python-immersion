# %% [markdown]
# # Importing libraries

# %%
import pandas as pd
import plotly.express as px

# %% [markdown]
# # Defining variables

# %%
df_main = pd.read_excel("/content/Action Table.xlsx", sheet_name = "Main")
df_main.head(10) #shows the 10 first lines of the sheet 'Main'
# Out:
#    Asset       Date  Final Value (R$)  Var. Day (%)  Var. Sem. (%)  \
# 0  USIM5 2024-01-26              9.50          5.20          11.76
# 1  CMIN3 2024-01-26              6.82          2.40           2.40
# 2  PETR3 2024-01-26             41.96          2.19           7.73
# 3  SUZB3 2024-01-26             52.91          2.04           2.14
# 4  CPFE3 2024-01-26             37.10          2.03           2.49
# 5  PRIO3 2024-01-26             45.69          1.98           2.42
# 6  PETR4 2024-01-26             39.96          1.73           6.47
# 7  VALE3 2024-01-26             69.50          1.66           2.06
# 8  MULT3 2024-01-26             28.19          1.58           2.03
# 9  ITUB4 2024-01-26             32.81          1.48          -0.39
#
#    Var. Mês (%)  Var. Ano (%)  Var. 12M (%)  Val. Mín  Val. Máx    Volume  \
# 0          2.26          2.26         15.97      9.18      9.56  319,16 M
# 1        -12.11        -12.11         50.56      6.66      6.86   32,65 M
# 2          7.64          7.64         77.55     40.81     42.34  436,69 M
# 3         -4.89         -4.89         18.85     51.89     53.17  162,55 M
# 4         -3.66         -3.66         20.70     36.37     37.32   73,42 M
# 5         -0.78         -0.78          8.08     44.25     45.69  319,92 M
# 6          7.30          7.30         95.01     38.91     40.09    1,64 B
# 7         -9.97         -9.97        -23.49     67.50     69.81    1,89 B
# 8         -0.81         -0.81         24.02     27.71     28.36  104,16 M
# 9         -3.36         -3.36         34.25     32.35     32.91   473,2 M
#
#    Variation %  Inicial Value (R$)  Number of Shares   Variation $   Result  \
# 0         0.05                9.03         515117391  241889725.43  Went up
# 1         0.02                6.66        1110559345  177515970.30  Went up
# 2         0.02               41.06        2379877655 2140059393.53  Went up
# 3         0.02               51.85         683452836  722946282.71  Went up
# 4         0.02               36.36         187732538  138573955.06  Went up
# 5         0.02               44.80         800010734  709687498.18  Went up
# 6         0.02               39.28        4566445852 3103136291.22  Went up
# 7         0.02               68.37        4196924316 4762926995.25  Went up
# 8         0.02               27.75         268505432  117732680.08  Went up
# 9         0.01               32.33        4801593832 2297591984.33  Went up
#
#             Name                       Segment  Age                  Cat. Age
# 0       Usiminas                    Siderurgia   82  Between 50 and 100 years
# 1  CSN Mineração                     Mineração   41        Less than 50 years
# 2      Petrobras                Petróleo e Gás  101    Greater than 100 years
# 3         Suzano              Papel e Celulose   39        Less than 50 years
# 4   CPFL Energia              Energia Elétrica  170    Greater than 100 years
# 5       PetroRio                Petróleo e Gás   41        Less than 50 years
# 6      Petrobras                Petróleo e Gás   29        Less than 50 years
# 7           Vale                     Mineração  103    Greater than 100 years
# 8      Multiplan              Shopping Centers   18        Less than 50 years
# 9  Itaú Unibanco  Serviços Financeiros (Banco)   37        Less than 50 years

# %%
df_total = pd.read_excel("/content/Action Table.xlsx", sheet_name = "Total")
df_total #shows the sheet 'Total'
# Out:
#                         Code  Theoretical Quantity
# 0                      RRRP3          235665566.00
# 1                      ALOS3          532616595.00
# 2                      ALPA4          176733968.00
# 3                      ABEV3         4394245879.00
# 4                      ARZZ3           62305891.00
# ..                       ...                   ...
# 84                     VBBR3         1114412532.00
# 85                     WEGE3         1481593024.00
# 86                     YDUQ3          289347914.00
# 87  Quantidade Teórica Total        96372098181.00
# 88                   Redutor           17047850.79
#
# [89 rows x 2 columns]

# %%
df_ticker = pd.read_excel("/content/Action Table.xlsx", sheet_name = "Ticker")
df_ticker #shows the sheet 'Ticker'
# Out:
#     Ticker            Name
# 0    MGLU3  Magazine Luiza
# 1    HAPV3         Hapvida
# 2    PETR4       Petrobras
# 3    B3SA3              B3
# 4    USIM5        Usiminas
# ..     ...             ...
# 530  TKNO3           Tekno
# 531  COCE6          Coelce
# 532  MGEL3         Mangels
# 533  CTSA8      Santanense
# 534  MMAQ4   Minasmáquinas
#
# [535 rows x 2 columns]

# %%
df_chatgpt = pd.read_excel("/content/Action Table.xlsx", sheet_name = "ChatGPT")
df_chatgpt #shows the sheet 'ChatGPT'
# Out:
#              Company                       Segment  Age
# 0           Usiminas                    Siderurgia   82
# 1      CSN Mineração                     Mineração   41
# 2          Petrobras                Petróleo e Gás  101
# 3             Suzano              Papel e Celulose   39
# 4       CPFL Energia              Energia Elétrica  170
# ..               ...                           ...  ...
# 75  Carrefour Brasil        Varejo (Supermercados)  185
# 76       Casas Bahia     Varejo (Eletrodomésticos)   45
# 77          Localiza  Serviços (Aluguel de Carros)   85
# 78               CVC  Turismo (Agência de Viagens)  146
# 79               GOL              Transporte Aéreo  132
#
# [80 rows x 3 columns]

# %% [markdown]
# # Copying the columns

# %%
df_main = df_main[['Asset',	'Date',	'Final Value (R$)',	'Var. Day (%)']].copy()
df_main
# Out:
#     Asset       Date  Final Value (R$)  Var. Day (%)
# 0   USIM5 2024-01-26              9.50          5.20
# 1   CMIN3 2024-01-26              6.82          2.40
# 2   PETR3 2024-01-26             41.96          2.19
# 3   SUZB3 2024-01-26             52.91          2.04
# 4   CPFE3 2024-01-26             37.10          2.03
# ..    ...        ...               ...           ...
# 76  CRFB3 2024-01-26             10.71         -2.45
# 77  BHIA3 2024-01-26              8.70         -2.46
# 78  RENT3 2024-01-26             56.24         -3.63
# 79  CVCB3 2024-01-26              3.07         -4.36
# 80  GOLL4 2024-01-26              5.92         -8.07
#
# [81 rows x 4 columns]

# %% [markdown]
# # Renaming the columns

# %%
df_main = df_main.rename(columns={'Final Value (R$)':'Final_Value',	'Var. Day (%)':'Var_Day_Pct'}).copy()
df_main
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct
# 0   USIM5 2024-01-26         9.50         5.20
# 1   CMIN3 2024-01-26         6.82         2.40
# 2   PETR3 2024-01-26        41.96         2.19
# 3   SUZB3 2024-01-26        52.91         2.04
# 4   CPFE3 2024-01-26        37.10         2.03
# ..    ...        ...          ...          ...
# 76  CRFB3 2024-01-26        10.71        -2.45
# 77  BHIA3 2024-01-26         8.70        -2.46
# 78  RENT3 2024-01-26        56.24        -3.63
# 79  CVCB3 2024-01-26         3.07        -4.36
# 80  GOLL4 2024-01-26         5.92        -8.07
#
# [81 rows x 4 columns]

# %%
df_main['Variation_Pct'] = df_main['Var_Day_Pct'] / 100
df_main['Inicial_Value'] = df_main['Final_Value'] / (df_main['Variation_Pct'] + 1)
df_main
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct  Variation_Pct  Inicial_Value
# 0   USIM5 2024-01-26         9.50         5.20           0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40           0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04           0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03           0.02          36.36
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63          -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.08           6.44
#
# [81 rows x 6 columns]

# %% [markdown]
# # Searching information from another sheet (VLOOKUP/PROCV = Merge)

# %%
df_main = df_main.merge(df_total, left_on = 'Asset', right_on = 'Code', how = 'left') #the column Code will merge with the column Asset, the main table is the left (Asset)
df_main
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct  Variation_Pct  Inicial_Value  \
# 0   USIM5 2024-01-26         9.50         5.20           0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40           0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04           0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03           0.02          36.36
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63          -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.08           6.44
#
#      Code  Theoretical Quantity
# 0   USIM5          515117391.00
# 1   CMIN3         1110559345.00
# 2   PETR3         2379877655.00
# 3   SUZB3          683452836.00
# 4   CPFE3          187732538.00
# ..    ...                   ...
# 76  CRFB3          533990587.00
# 77  BHIA3           94843047.00
# 78  RENT3          853202347.00
# 79  CVCB3          525582771.00
# 80  GOLL4          198184909.00
#
# [81 rows x 8 columns]

# %%
df_main = df_main.drop(columns = {'Code'}) #deleting the column Code
df_main = df_main.rename(columns = {'Theoretical Quantity':'Theoretical_Quantity'}).copy()
df_main
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct  Variation_Pct  Inicial_Value  \
# 0   USIM5 2024-01-26         9.50         5.20           0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40           0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04           0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03           0.02          36.36
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63          -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.08           6.44
#
#     Theoretical_Quantity
# 0           515117391.00
# 1          1110559345.00
# 2          2379877655.00
# 3           683452836.00
# 4           187732538.00
# ..                   ...
# 76          533990587.00
# 77           94843047.00
# 78          853202347.00
# 79          525582771.00
# 80          198184909.00
#
# [81 rows x 7 columns]

# %% [markdown]
# # Creating the column variation

# %%
df_main['Variation'] = (df_main['Final_Value'] - df_main['Inicial_Value']) * df_main['Theoretical_Quantity']
df_main
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct  Variation_Pct  Inicial_Value  \
# 0   USIM5 2024-01-26         9.50         5.20           0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40           0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04           0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03           0.02          36.36
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63          -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.08           6.44
#
#     Theoretical_Quantity      Variation
# 0           515117391.00   241889725.43
# 1          1110559345.00   177515970.30
# 2          2379877655.00  2140059393.53
# 3           683452836.00   722946282.71
# 4           187732538.00   138573955.06
# ..                   ...            ...
# 76          533990587.00  -143635530.57
# 77           94843047.00   -20810240.84
# 78          853202347.00 -1807432634.46
# 79          525582771.00   -73557408.06
# 80          198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %% [markdown]
# # Formating values

# %%
pd.options.display.float_format = '{:.2f}'.format
df_main
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct  Variation_Pct  Inicial_Value  \
# 0   USIM5 2024-01-26         9.50         5.20           0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40           0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04           0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03           0.02          36.36
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63          -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.08           6.44
#
#     Theoretical_Quantity      Variation
# 0           515117391.00   241889725.43
# 1          1110559345.00   177515970.30
# 2          2379877655.00  2140059393.53
# 3           683452836.00   722946282.71
# 4           187732538.00   138573955.06
# ..                   ...            ...
# 76          533990587.00  -143635530.57
# 77           94843047.00   -20810240.84
# 78          853202347.00 -1807432634.46
# 79          525582771.00   -73557408.06
# 80          198184909.00  -102993202.62
#
# [81 rows x 8 columns]

# %% [markdown]
# # Transforming the column to INT

# %%
df_main['Theoretical_Quantity'] = df_main['Theoretical_Quantity'].astype(int)
df_main
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct  Variation_Pct  Inicial_Value  \
# 0   USIM5 2024-01-26         9.50         5.20           0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40           0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04           0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03           0.02          36.36
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63          -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.08           6.44
#
#     Theoretical_Quantity      Variation
# 0              515117391   241889725.43
# 1             1110559345   177515970.30
# 2             2379877655  2140059393.53
# 3              683452836   722946282.71
# 4              187732538   138573955.06
# ..                   ...            ...
# 76             533990587  -143635530.57
# 77              94843047   -20810240.84
# 78             853202347 -1807432634.46
# 79             525582771   -73557408.06
# 80             198184909  -102993202.62
#
# [81 rows x 8 columns]

# %% [markdown]
# # Result (went up, went down or kept)

# %%
#if x > 0 = Went up; else x < 0 = Went down; else = Kept
df_main['Result'] = df_main['Variation'].apply(lambda x: 'Went up' if x > 0 else ('Went down' if x < 0 else 'Kept'))
df_main
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct  Variation_Pct  Inicial_Value  \
# 0   USIM5 2024-01-26         9.50         5.20           0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40           0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04           0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03           0.02          36.36
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63          -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.08           6.44
#
#     Theoretical_Quantity      Variation     Result
# 0              515117391   241889725.43    Went up
# 1             1110559345   177515970.30    Went up
# 2             2379877655  2140059393.53    Went up
# 3              683452836   722946282.71    Went up
# 4              187732538   138573955.06    Went up
# ..                   ...            ...        ...
# 76             533990587  -143635530.57  Went down
# 77              94843047   -20810240.84  Went down
# 78             853202347 -1807432634.46  Went down
# 79             525582771   -73557408.06  Went down
# 80             198184909  -102993202.62  Went down
#
# [81 rows x 9 columns]

# %% [markdown]
# # Searching the name of the company

# %%
df_main = df_main.merge(df_ticker, left_on = 'Asset', right_on = 'Ticker', how = 'left')
df_main = df_main.drop(columns = {'Ticker'})
df_main
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct  Variation_Pct  Inicial_Value  \
# 0   USIM5 2024-01-26         9.50         5.20           0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40           0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 3   SUZB3 2024-01-26        52.91         2.04           0.02          51.85
# 4   CPFE3 2024-01-26        37.10         2.03           0.02          36.36
# ..    ...        ...          ...          ...            ...            ...
# 76  CRFB3 2024-01-26        10.71        -2.45          -0.02          10.98
# 77  BHIA3 2024-01-26         8.70        -2.46          -0.02           8.92
# 78  RENT3 2024-01-26        56.24        -3.63          -0.04          58.36
# 79  CVCB3 2024-01-26         3.07        -4.36          -0.04           3.21
# 80  GOLL4 2024-01-26         5.92        -8.07          -0.08           6.44
#
#     Theoretical_Quantity      Variation     Result              Name
# 0              515117391   241889725.43    Went up          Usiminas
# 1             1110559345   177515970.30    Went up     CSN Mineração
# 2             2379877655  2140059393.53    Went up         Petrobras
# 3              683452836   722946282.71    Went up            Suzano
# 4              187732538   138573955.06    Went up      CPFL Energia
# ..                   ...            ...        ...               ...
# 76             533990587  -143635530.57  Went down  Carrefour Brasil
# 77              94843047   -20810240.84  Went down       Casas Bahia
# 78             853202347 -1807432634.46  Went down          Localiza
# 79             525582771   -73557408.06  Went down               CVC
# 80             198184909  -102993202.62  Went down               GOL
#
# [81 rows x 10 columns]

# %% [markdown]
# # Searching the segment and the age of the company

# %%
df_main = df_main.merge(df_chatgpt, left_on = 'Name', right_on = 'Company', how = 'left')
df_main = df_main.drop(columns = {'Company'})
df_main
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct  Variation_Pct  Inicial_Value  \
# 0   USIM5 2024-01-26         9.50         5.20           0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40           0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04           0.02          51.85
# ..    ...        ...          ...          ...            ...            ...
# 80  CRFB3 2024-01-26        10.71        -2.45          -0.02          10.98
# 81  BHIA3 2024-01-26         8.70        -2.46          -0.02           8.92
# 82  RENT3 2024-01-26        56.24        -3.63          -0.04          58.36
# 83  CVCB3 2024-01-26         3.07        -4.36          -0.04           3.21
# 84  GOLL4 2024-01-26         5.92        -8.07          -0.08           6.44
#
#     Theoretical_Quantity      Variation     Result              Name  \
# 0              515117391   241889725.43    Went up          Usiminas
# 1             1110559345   177515970.30    Went up     CSN Mineração
# 2             2379877655  2140059393.53    Went up         Petrobras
# 3             2379877655  2140059393.53    Went up         Petrobras
# 4              683452836   722946282.71    Went up            Suzano
# ..                   ...            ...        ...               ...
# 80             533990587  -143635530.57  Went down  Carrefour Brasil
# 81              94843047   -20810240.84  Went down       Casas Bahia
# 82             853202347 -1807432634.46  Went down          Localiza
# 83             525582771   -73557408.06  Went down               CVC
# 84             198184909  -102993202.62  Went down               GOL
#
#                          Segment  Age
# 0                     Siderurgia   82
# 1                      Mineração   41
# 2                 Petróleo e Gás  101
# 3                 Petróleo e Gás   29
# 4               Papel e Celulose   39
# ..                           ...  ...
# 80        Varejo (Supermercados)  185
# 81     Varejo (Eletrodomésticos)   45
# 82  Serviços (Aluguel de Carros)   85
# 83  Turismo (Agência de Viagens)  146
# 84              Transporte Aéreo  132
#
# [85 rows x 12 columns]

# %% [markdown]
# # Age (Greater than 100 years; Less than 50 years; Between 50 and 100 years)

# %%
# if x > 100 = Greater than 100 years; else x < 50 = Less than 50 years; else = Between 50 and 100 years
df_main['Age_Cat'] = df_main['Age'].apply(lambda x: 'Greater than 100 years' if x > 100 else ('Less than 50 years' if x < 50 else 'Between 50 and 100 years'))
df_main
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct  Variation_Pct  Inicial_Value  \
# 0   USIM5 2024-01-26         9.50         5.20           0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.40           0.02           6.66
# 2   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 3   PETR3 2024-01-26        41.96         2.19           0.02          41.06
# 4   SUZB3 2024-01-26        52.91         2.04           0.02          51.85
# ..    ...        ...          ...          ...            ...            ...
# 80  CRFB3 2024-01-26        10.71        -2.45          -0.02          10.98
# 81  BHIA3 2024-01-26         8.70        -2.46          -0.02           8.92
# 82  RENT3 2024-01-26        56.24        -3.63          -0.04          58.36
# 83  CVCB3 2024-01-26         3.07        -4.36          -0.04           3.21
# 84  GOLL4 2024-01-26         5.92        -8.07          -0.08           6.44
#
#     Theoretical_Quantity      Variation     Result              Name  \
# 0              515117391   241889725.43    Went up          Usiminas
# 1             1110559345   177515970.30    Went up     CSN Mineração
# 2             2379877655  2140059393.53    Went up         Petrobras
# 3             2379877655  2140059393.53    Went up         Petrobras
# 4              683452836   722946282.71    Went up            Suzano
# ..                   ...            ...        ...               ...
# 80             533990587  -143635530.57  Went down  Carrefour Brasil
# 81              94843047   -20810240.84  Went down       Casas Bahia
# 82             853202347 -1807432634.46  Went down          Localiza
# 83             525582771   -73557408.06  Went down               CVC
# 84             198184909  -102993202.62  Went down               GOL
#
#                          Segment  Age                   Age_Cat
# 0                     Siderurgia   82  Between 50 and 100 years
# 1                      Mineração   41        Less than 50 years
# 2                 Petróleo e Gás  101    Greater than 100 years
# 3                 Petróleo e Gás   29        Less than 50 years
# 4               Papel e Celulose   39        Less than 50 years
# ..                           ...  ...                       ...
# 80        Varejo (Supermercados)  185    Greater than 100 years
# 81     Varejo (Eletrodomésticos)   45        Less than 50 years
# 82  Serviços (Aluguel de Carros)   85  Between 50 and 100 years
# 83  Turismo (Agência de Viagens)  146    Greater than 100 years
# 84              Transporte Aéreo  132    Greater than 100 years
#
# [85 rows x 13 columns]

# %% [markdown]
# # Max, Min, Mean

# %%
bigger = df_main['Variation'].max()
smaller = df_main['Variation'].min()
average = df_main['Variation'].mean()

#average of those who went up
average_up = df_main[df_main['Result'] == 'Went up']['Variation'].mean()
#average of those who went down
average_down = df_main[df_main['Result'] == 'Went down']['Variation'].mean()

#printing the results
print(f"Bigger\t R$ {bigger:,.2f}")
print(f"Smaller\t R$ {smaller:,.2f}")
print(f"Average\t R$ {average:,.2f}")
print(f"Went up average\t R$ {average_up:,.2f}")
print(f"Went down average\t R$ {average_down:,.2f}")
# Out:
# Bigger	 R$ 4,762,926,995.25
# Smaller	 R$ -1,807,432,634.46
# Average	 R$ 229,644,360.94
# Went up average	 R$ 538,720,638.36
# Went down average	 R$ -181,109,141.75

# %% [markdown]
# # Segmentation that went down

# %%
df_segment_wentup = df_main[df_main['Result'] == 'Went up']
df_segment_wentup
# Out:
#     Asset       Date  Final_Value  Var_Day_Pct  Variation_Pct  Inicial_Value  \
# 0   USIM5 2024-01-26         9.50         5.20           0.05           9.03
# 1   CMIN3 2024-01-26         6.82         2.
# 13                               Petroquímica  121    Greater than 100 years
# 14                           Transporte Aéreo   86  Between 50 and 100 years
# 15                             Petróleo e Gás   40        Less than 50 years
# 16                           Energia Elétrica   27        Less than 50 years
# 17                                 Siderurgia   75  Between 50 and 100 years
# 18                                   Educação  173    Greater than 100 years
# 19               Distribuição de Combustíveis   33        Less than 50 years
# 20                           Construção Civil   66  Between 50 and 100 years
# 21                          Varejo (Calçados)  172    Greater than 100 years
# 22               Serviços Financeiros (Banco)   79  Between 50 and 100 years
# 23               Serviços Financeiros (Banco)   42        Less than 50 years
# 24                          Alimentos (Carne)  181    Greater than 100 years
# 25                     Varejo (Supermercados)    9        Less than 50 years
# 26                    Alimentos (Processados)    2        Less than 50 years
# 27                           Telecomunicações  163    Greater than 100 years
# 28         Logística (Transporte Ferroviário)   67  Between 50 and 100 years
# 29  Serviços Financeiros (Meios de Pagamento)   25        Less than 50 years
# 30                                          ?   15        Less than 50 years
# 31                           Telecomunicações    1        Less than 50 years
# 32                         Holding Financeira    4        Less than 50 years
# 33                Tecnologia (Hospedagem Web)  185    Greater than 100 years
# 34                             Petróleo e Gás   21        Less than 50 years
# 35                         Holding Financeira   92  Between 50 and 100 years
# 36               Serviços Financeiros (Banco)  114    Greater than 100 years
# 37                         Varejo (Farmácias)   22        Less than 50 years
# 38                                 Siderurgia  167    Greater than 100 years
# 39                        Energia e Logística   58  Between 50 and 100 years
# 40                          Alimentos (Carne)  153    Greater than 100 years
# 41             Varejo (Lojas de Departamento)  188    Greater than 100 years
# 42               Serviços Financeiros (Banco)   79  Between 50 and 100 years
# 43               Serviços Financeiros (Banco)   42        Less than 50 years
# 44                                 Siderurgia  120    Greater than 100 years
# 45                  Energia (Açúcar e Etanol)  188    Greater than 100 years
# 46                           Energia Elétrica  177    Greater than 100 years
# 47            Logística (Aluguel de Veículos)  136    Greater than 100 years

# %%
df_segments = df_segment_wentup.groupby('Segment')['Variation'].sum().reset_index()
df_segments
# Out:
#                                       Segment      Variation
# 0                                           ?    18068446.61
# 1                           Alimentos (Carne)   174787913.53
# 2                     Alimentos (Processados)   233045769.57
# 3                            Construção Civil    37525872.38
# 4                Distribuição de Combustíveis   388705223.96
# 5                                    Educação    72295838.99
# 6                   Energia (Açúcar e Etanol)    11571106.42
# 7                            Energia Elétrica   682315640.01
# 8                         Energia e Logística   127229653.18
# 9                          Holding Financeira   416092244.42
# 10            Logística (Aluguel de Veículos)     4131341.16
# 11         Logística (Transporte Ferroviário)   229771333.63
# 12                                  Mineração  4940442965.55
# 13                           Papel e Celulose   722946282.71
# 14                               Petroquímica    69054317.64
# 15                             Petróleo e Gás 11336484517.00
# 16                          Saúde (Hospitais)   453917907.01
# 17               Serviços Financeiros (Banco)  4636679965.25
# 18  Serviços Financeiros (Meios de Pagamento)    43657683.38
# 19                           Shopping Centers   117732680.08
# 20                                 Siderurgia   489935930.93
# 21                Tecnologia (Hospedagem Web)    15598886.65
# 22                           Telecomunicações   292938114.42
# 23                           Transporte Aéreo    65452205.55
# 24                          Varejo (Calçados)    41021792.09
# 25                         Varejo (Farmácias)   202352473.74
# 26             Varejo (Lojas de Departamento)    28493619.27
# 27                     Varejo (Supermercados)     6340916.22

# %% [markdown]
# # Result - Variation

# %%
df_result = df_main.groupby('Result')['Variation'].sum().reset_index()
df_result
# Out:
#       Result      Variation
# 0       Kept           0.00
# 1  Went down -6338819961.32
# 2    Went up 25858590641.35

# %% [markdown]
# # Analysis per age group

# %%
df_age_group = df_main.groupby('Age_Cat')['Variation'].sum().reset_index()
df_age_group
# Out:
#                     Age_Cat      Variation
# 0  Between 50 and 100 years -1913729553.02
# 1    Greater than 100 years 10708072752.28
# 2        Less than 50 years 10725427480.78

# %%
df_age_group = df_main.groupby('Age_Cat')['Variation'].nunique().reset_index()
df_age_group.columns = ['Age_Cat', 'Quantity_of_Companies']
df_age_group
# Out:
#                     Age_Cat  Quantity_of_Companies
# 0  Between 50 and 100 years                     19
# 1    Greater than 100 years                     34
# 2        Less than 50 years                     31

# %% [markdown]
# # Graphics

# %%
#creating the bar graphic
fig = px.bar(df_result, x = 'Result', y = 'Variation', text = 'Variation', title = 'Variation per Result')

#updating text formatting
fig.update_traces(texttemplate='%{text:.2f}', textposition='outside')

#customizing the chart layout
fig.update_layout(yaxis=dict(title='Variation'), xaxis=dict(title='Result'))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b3a9d21a-f355-4825-8378-9607eb92c34d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b3a9d21a-f355-4825-8378-9607eb92c34d")) {                    Plotly.newPlot(                        "b3a9d21a-f355-4825-8378-9607eb92c34d",                        [{"alignmentgroup":"True","hovertemplate":"Result=%{x}\u003cbr\u003eVariation=%{text}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"text":[0.0,-6338819961.31535,25858590641.34758],"textposition":"outside","x":["Kept","Went down","Went up"],"xaxis":"x","y":[0.0,-6338819961.31535,25858590641.34758],"yaxis":"y","type":"bar","texttemplate":"%{text:.2f}"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidi ...

# %%
pizza = px.pie(df_segments, names = 'Segment', values = 'Variation', title = 'Variations that Rose')
pizza.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8630b9d2-b991-40b5-80d9-a3907dfe367b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8630b9d2-b991-40b5-80d9-a3907dfe367b")) {                    Plotly.newPlot(                        "8630b9d2-b991-40b5-80d9-a3907dfe367b",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Segment=%{label}\u003cbr\u003eVariation=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["?","Alimentos (Carne)","Alimentos (Processados)","Constru\u00e7\u00e3o Civil","Distribui\u00e7\u00e3o de Combust\u00edveis","Educa\u00e7\u00e3o","Energia (A\u00e7\u00facar e Etanol)","Energia El\u00e9trica","Energia e Log\u00edstica","Holding Financeira","Log\u00edstica (Aluguel de Ve\u00edculos)","Log\u00edstica (Transporte Ferrovi\u00e1rio)","Minera\u00e7\u00e3o","Papel e Celulose","Petroqu\u00edmica","Petr\u00f3leo e G\u00e1s","Sa\u00fade (Hospitais)","Servi\u00e7os Financeiros (Banco)","Servi\u00e7os Financeiros (Meios de Pagamento)","Shopping Centers","Siderurgia","Tecnologia (Hospedagem Web)","Telecomunica\u00e7\u00f5es","Transporte A\u00e9reo","Varejo (Cal\u00e7ados)","Varejo (Farm\u00e1cias)","Varejo (Lojas de Departamento)","Varejo (Supermercados)"],"legendgroup":"","name":"","showlegend":true,"values":[18068446.60998324,174787913.52611017,233045769.5663398,37525872.37728388,388705223.95601785,72295838.98616095,11571106.417007603,682315640.0120441,127229653.18222687,416092244.423763,4131341.15789051,229771333.63468358,4940442965.550434,722946282.7090385,69054317.63603853,11336484517.004236,453917907.01324,4636679965.247721,43657683.37554085,117732680.0784251,489935930.9283229,15598886.650556229,292938114.42357796,65452205.552800186,41021792.09077153,202352473.73982856,28493619.274394516,6340916.223143544],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3 ...
